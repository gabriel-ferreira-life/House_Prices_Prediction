# %%
print("Rafael is nice")
# Out:
# Rafael is nice

# %%
#for data
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

#math
import math

#plot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

#machine learning 
import sklearn 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-b3c54a058618>", line 10, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 1015, in <module>
#     rcParams = rc_params()
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 878, in rc_params
#     return rc_params_from_file(matplotlib_fname(), fail_on_error)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 731, in matplotlib_fname
#     for fname in gen_candidates():
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 720, in gen_candidates
#     yield os.path.join(os.getcwd(), 'matplotlibrc')
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 737, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/posixpath.py", line 379, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-b3c54a058618>", line 10, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 1015, in <module>
#     rcParams = rc_params()
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 878, in rc_params
#     return rc_params_from_file(matplotlib_fname(), fail_on_error)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 731, in matplotlib_fname
#     for fname in gen_candidates():
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 720, in gen_candidates
#     yield os.path.join(os.getcwd(), 'matplotlibrc')
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 737, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/posixpath.py", line 379, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-b3c54a058618>", line 10, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 1015, in <module>
#     rcParams = rc_params()
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 878, in rc_params
#     return rc_params_from_file(matplotlib_fname(), fail_on_error)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 731, in matplotlib_fname
#     for fname in gen_candidates():
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 720, in gen_candidates
#     yield os.path.join(os.getcwd(), 'matplotlibrc')
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3071, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2046, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1335, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1210, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 737, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/gabrielvictorgomesferreira/opt/anaconda3/lib/python3.8/posixpath.py", line 379, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
